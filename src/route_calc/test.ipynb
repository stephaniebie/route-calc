# %%
from Graph import Graph

# %%
g = Graph("Rush Hour")
g.add_edge('A', 'B', 1, risk=True)
g.add_edge('A', 'C', 4, risk=True)
g.add_edge('B', 'C', 2, risk=True)
g.add_edge('B', 'D', 5, risk=True)
g.add_edge('C', 'D', 1, risk=True)
g.add_edge('A', 'E', 3, risk=True)
g.add_edge('E', 'D', 2, risk=True)
g.add_edge('E', 'F', 4, risk=True)
g.add_edge('F', 'C', 7, risk=True)
g.add_edge('D', 'F', 6, risk=True)

print(g)
# Out:
# Accident on edge B D
# Accident on edge F C
# Graph with 6 nodes
#  Adjacency List: {'A': [('B', 1), ('C', 11), ('E', 6)], 'B': [('A', 1), ('C', 3), ('D', 75)], 'C': [('A', 11), ('B', 3), ('D', 2), ('F', 195)], 'D': [('B', 75), ('C', 2), ('E', 2), ('F', 10)], 'E': [('A', 6), ('D', 2), ('F', 7)], 'F': [('E', 7), ('C', 195), ('D', 10)]}

# %%
g.dijkstra('A', 'F')
# Out:
# (['A', 'E', 'F'], 12)
